# %%
# %%capture
# !pip install pandas
# !pip install numpy
# !pip install tensorflow
# !pip install keras
# !pip install sklearn
# !pip install matplotlib
# !pip install seaborn
# !pip install unidecode
# !pip install -U imbalanced-learn
# !pip3 install pickle5

# %%
import tensorflow as tf
import pandas as pd
import warnings
import unidecode
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle5 as pickle
import random
import os
import re
import time
import nltk
nltk.download('stopwords')

from sklearn.metrics import confusion_matrix
from imblearn.over_sampling import RandomOverSampler
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from tensorflow import keras
from keras.models import Sequential, Model
from keras.layers import Reshape, Dense, Dropout, Flatten, Input, MaxPooling2D, Convolution2D, Embedding, Concatenate
from keras.regularizers import l2
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import f1_score

sw = set(stopwords.words('english'))
os.environ['PYTHONHASHSEED']=str(23)
tf.random.set_seed(23)
random.seed(23)
warnings.filterwarnings('ignore')
np.random.seed(23)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Preprocessing

# %%
def remove_username(text):
  text = re.sub(r'\@[^\s]+', ' ', text)
  return text

def remove_newline(text):
  text = text.replace('\n', ' ')
  return text

def only_letters(text):
  text = re.sub(r'[^a-záâàãéêèẽíìîĩóòõôúùũû\s]+', ' ', text)
  return text

def remove_link(text):
  text = re.sub(r'www\.?[^\s]+', ' ', text)
  return text

def remove_hyperlink(text):
  text = re.sub(r'\<.?\>', ' ', text)
  return text

def remove_accent(text):
  text = unidecode.unidecode(text)
  return text

def adjustment_text(text):
  text = re.sub(r'\s+', ' ', text)
  text = text.strip()
  return text

def remove_stopwords(text):
  text = [word for word in text.split() if word not in sw]
  text = ' '.join(text)
  return text

def remove_spam(text):
  text = re.sub(r'\&amp', ' ', text)
  text = re.sub(r'\&lt', ' ', text)
  text = re.sub(r'\&gt', ' ', text)
  text = re.sub(r'\#follow|\#followme|\#like|\#f4f|\#photooftheday', ' ', text)
  return text

def remove_slangs(text):
  text = re.sub(r' b4 ', ' before ', text)
  text = re.sub(r' 2b ', ' to be ', text)
  text = re.sub(r' 2morrow ', ' tomorrow ', text)
  text = re.sub(r' rn ', ' right now ', text)
  text = re.sub(r' brb ', ' be right back ', text)
  text = re.sub(r' mb ', ' my bad ', text)
  text = re.sub(r' luv ', ' love ', text)
  text = re.sub(r' b ', ' be ', text)
  text = re.sub(r' r ', ' are ', text)
  text = re.sub(r' u ', ' you ', text)
  text = re.sub(r' y ', ' why ', text)
  text = re.sub(r' ur ', ' your ', text)
  text = re.sub(r' hbd ', ' happy birthday ', text)
  text = re.sub(r' bday ', ' birthday ', text)
  text = re.sub(r' bihday ', ' birthday ', text)
  text = re.sub(r' omg ', ' oh my god ', text)
  text = re.sub(r' lol ', ' laughing out loud ', text)
  return text

def remove_abbreviations(text):
  text = re.sub(r" can\'t ", " can not ", text)
  text = re.sub(r" i\'m ", " i am ", text)
  text = re.sub(r" i\'ll ", " i will ", text)
  text = re.sub(r" i\'d ", " i would ", text)
  text = re.sub(r" i\'ve ", " i have ", text)
  text = re.sub(r" ain\'t ", " am not ", text)
  text = re.sub(r" haven\'t ", " have not ", text)
  text = re.sub(r" hasn\'t ", " has not ", text)
  text = re.sub(r" can\'t ", " can not ", text)
  text = re.sub(r" won\'t ", " will not ", text)
  text = re.sub(r" you\'re ", " you are ", text)
  text = re.sub(r" we\'re ", " we are ", text)
  text = re.sub(r" they\'re ", " they are ", text)
  text = re.sub(r" he\'s ", " he is ", text)
  text = re.sub(r" she\'s ", " she is ", text)
  text = re.sub(r" it\'s ", " it is ", text)
  text = re.sub(r" don\'t ", " do not ", text)
  text = re.sub(r" doesn\'t ", " does not ", text)
  text = re.sub(r" wouldn\'t ", " would not ", text)
  text = re.sub(r" couldn\'t ", " could not ", text)
  text = re.sub(r" shouldn\'t ", " should not ", text)
  return text

def remove_one_len_word(text):
  text = re.sub(r'\b[a-z]\b', ' ', text)
  return text

def preprocessing(data):
  data['cleaned_tweet'] = data['tweet'].apply(str)
  data['cleaned_tweet'] = data['cleaned_tweet'].apply(lambda x: x.lower())
  data['cleaned_tweet'] = data['cleaned_tweet'].apply(remove_newline)
  data['cleaned_tweet'] = data['cleaned_tweet'].apply(remove_hyperlink)
  data['cleaned_tweet'] = data['cleaned_tweet'].apply(remove_spam)
  data['cleaned_tweet'] = data['cleaned_tweet'].apply(remove_link)
  data['cleaned_tweet'] = data['cleaned_tweet'].apply(remove_username)
  data['cleaned_tweet'] = data['cleaned_tweet'].apply(remove_abbreviations)
  data['cleaned_tweet'] = data['cleaned_tweet'].apply(only_letters)
  data['cleaned_tweet'] = data['cleaned_tweet'].apply(remove_accent)
  data['cleaned_tweet'] = data['cleaned_tweet'].apply(remove_slangs)
  data['cleaned_tweet'] = data['cleaned_tweet'].apply(remove_stopwords)
  data['cleaned_tweet'] = data['cleaned_tweet'].apply(remove_one_len_word)
  data['cleaned_tweet'] = data['cleaned_tweet'].apply(adjustment_text)
  return data

# %% [markdown]
# from google.colab import files
# uploaded = files.upload()

# %% [markdown]
# !unzip tokenizer_CNN_seed23

# %%
model = keras.models.load_model('model_110_filters.h5')
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 300)      14752500    input_3[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 30, 300, 1)   0           embedding[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 1, 110)   99110       reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 27, 1, 110)   132110      reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 26, 1, 110)   165110      reshape_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 27, 1, 110)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 26, 1, 110)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 25, 1, 110)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 78, 1, 110)   0           max_pooling2d_6[0][0]
#                                                                  max_pooling2d_7[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 8580)         0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8580)         0           flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            8581        dropout_2[0][0]
# ==================================================================================================
# Total params: 15,157,411
# Trainable params: 15,157,411
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# plt.figure(figsize = (10, 7))
# predicted = (model.predict(X_validation) > 0.5).astype("int32")
# matrix = confusion_matrix(y_validation, predicted, labels=[0, 1])
# sns.set(font_scale=1.4)
# sns.heatmap(matrix, annot=True, cmap="Blues", fmt='d', annot_kws={"size": 16})
# plt.xlabel('Classe prevista')
# plt.ylabel('Classe real')
# plt.savefig('matriz_confusao.jpg')

# %%
normal_data = pd.read_csv('Data/train.csv')
normal_data = normal_data.drop(columns=['id'])
normal_data.head()
# Out:
#    label                                              tweet
# 0      0   @user when a father is dysfunctional and is s...
# 1      0  @user @user thanks for #lyft credit i can't us...
# 2      0                                bihday your majesty
# 3      0  #model   i love u take with u all the time in ...
# 4      0             factsguide: society now    #motivation

# %%
normal_data.shape
# Out:
# (31962, 2)

# %%
preprocessed_data = normal_data.copy()
preprocessed_data = preprocessing(preprocessed_data)
preprocessed_data = preprocessed_data.replace('None', pd.NA)
preprocessed_data = preprocessed_data.dropna()
preprocessed_data = preprocessed_data.drop_duplicates()
preprocessed_data = preprocessed_data.drop(columns=['tweet'])
preprocessed_data = preprocessed_data.rename(columns={'cleaned_tweet': 'tweet'})
preprocessed_data.head()
# Out:
#    label                                              tweet
# 0      0  father dysfunctional selfish drags kids dysfun...
# 1      0  thanks lyft credit use cause offer wheelchair ...
# 2      0                                   birthday majesty
# 3      0                               model love take time
# 4      0                      factsguide society motivation

# %%
preprocessed_data.shape
# Out:
# (29530, 2)

# %%
ros = RandomOverSampler(random_state=23, sampling_strategy='minority')
X_resampled, y_resampled = ros.fit_resample(preprocessed_data[['tweet']], preprocessed_data['label'])
data_preprocessing_augmentation = pd.concat([X_resampled, y_resampled], axis=1)
data_preprocessing_augmentation.head()
# Out:
#                                                tweet  label
# 0  father dysfunctional selfish drags kids dysfun...      0
# 1  thanks lyft credit use cause offer wheelchair ...      0
# 2                                   birthday majesty      0
# 3                               model love take time      0
# 4                      factsguide society motivation      0

# %%
ros = RandomOverSampler(random_state=23, sampling_strategy='minority')
X_resampled, y_resampled = ros.fit_resample(normal_data[['tweet']], normal_data['label'])
data_augmentation = pd.concat([X_resampled, y_resampled], axis=1)
data_augmentation.head()
# Out:
#                                                tweet  label
# 0   @user when a father is dysfunctional and is s...      0
# 1  @user @user thanks for #lyft credit i can't us...      0
# 2                                bihday your majesty      0
# 3  #model   i love u take with u all the time in ...      0
# 4             factsguide: society now    #motivation      0

# %%
data_augmentation.shape
# Out:
# (59440, 2)

# %% [markdown]
# with open(r"content/Tokenizer/tokenizer.pickle", "rb") as output_file:
#     tokenizer_cnn = pickle.load(output_file)

# %%
all_messages = pd.concat([data_preprocessing_augmentation,
                          preprocessed_data,
                          normal_data,
                          data_augmentation], axis=0)

all_messages = all_messages.reset_index(drop=True)

tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_messages['tweet'].values)

# %% [markdown]
# teste = pd.DataFrame({'tweet': ["the next school year is the year for exams.ð¯ can't think about that ð­ #school #exams   #hate #imagine #actorslife #revolutionschool #girl",
#                                 "we won!!! love the land!!! #allin #cavs #champions #cleveland #clevelandcavaliers  â¦ ",
#                                 "it was a hard monday due to cloudy weather. disabling oxygen production for today. #goodnight #badmonday "]})
#
# teste['tokenized'] = tokenizer.texts_to_sequences(teste['tweet'].values)
# teste['tokenized_cnn'] = tokenizer_cnn.texts_to_sequences(teste['tweet'].values)
# teste.head()

# %% [markdown]
# teste['tokenized_cnn'].equals(teste['tokenized'])

# %% [markdown]
# ## Tokenizer

# %% [markdown]
# with open(r"tokenizer_rand_augmentantion.pickle", "rb") as output_file:
#     tokenizer = pickle.load(output_file)

# %% [markdown]
# ## Parameters

# %%
non_linearity_function = 'relu'
kernel_size = [3, 4, 5]
filters = 100
dropout_rate = 0.5
l2_constraint = 3
epochs = 10
batch_size = 100
embedding_dim = 300
length_size = 30

# %% [markdown]
# ## Predict

# %%
def predict(model, epoch):

  test = pd.read_csv('Data/test.csv')
  # test = preprocessing(test)
  test['tokenized'] = tokenizer.texts_to_sequences(test['tweet'].values)
  
  X_test = pad_sequences(sequences = test['tokenized'],
                         maxlen = length_size,
                         padding = 'post')

  predicted = (model.predict(X_test) > 0.5).astype("int32")
  prediction = pd.DataFrame()
  prediction['id'] = test['id']
  prediction['label'] = predicted
  prediction.to_csv('Submission/{}_dropout.csv'.format(epoch), index=False)

# %%
def generate_cm(model, X_validation, y_validation, parametro, valor):

  plt.figure(figsize = (10, 7))
  predicted_validation = (model.predict(X_validation) > 0.5).astype("int32")
  matrix = confusion_matrix(y_validation, predicted_validation, labels=[0, 1])
  sns.set(font_scale=1.4)
  sns.heatmap(matrix, annot=True, cmap="Blues", fmt='d', annot_kws={"size": 16})
  plt.xlabel('Classe prevista')
  plt.ylabel('Classe real')
  
  plt.savefig('Images/matriz_confusao_' + parametro + '_' + str(valor) + '.jpg')

# %% [markdown]
# ## Model

# %%
from keras.models import model_from_json

def cnn_rand(dropout):

  model.layers[9].rate = dropout
  
  new_model = model_from_json(model.to_json())

  new_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

  history_random = new_model.fit(X_train, 
                                 y_train,
                                 batch_size=batch_size,
                                 epochs=epochs,
                                 validation_data=(X_validation, y_validation))
  
  predicted_validation = (new_model.predict(X_validation) > 0.5).astype("int32")
  score = f1_score(y_validation, predicted_validation, average='weighted')
  score = round(score, 4)

  generate_cm(new_model, X_validation, y_validation, 'dropout', dropout)
  save_model(new_model, dropout)
  predict(new_model, dropout)
  
  return score

# %%
def save_model(modelo, epoch):
  file_name = 'model_'
  file_name = file_name + str(epoch) + '_dropout.h5'
  modelo.save('Model/' + file_name)

# %% [markdown]
# ## Main

# %%
#tokenizer = Tokenizer()
#tokenizer.fit_on_texts(data_augmentation['tweet'].values)
data_augmentation['tokenized'] = tokenizer.texts_to_sequences(data_augmentation['tweet'].values)
vocab_size = len(tokenizer.word_index) + 1

X = pad_sequences(sequences = data_augmentation['tokenized'],
                  maxlen = length_size,
                  padding = 'post')

y = data_augmentation['label']

X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.15, random_state=23)

# %% [markdown]
# test = pd.read_csv('Data/test.csv')
# test = preprocessing(test)
# test['tokenized'] = tokenizer.texts_to_sequences(test['cleaned_tweet'].values)
#
# X_test = pad_sequences(sequences = test['tokenized'],
#                        maxlen = length_size,
#                        padding = 'post')
#
# predicted = (model.predict(X_test) > 0.5).astype("int32")
# prediction = pd.DataFrame()
# prediction['id'] = test['id']
# prediction['label'] = predicted
# prediction.to_csv('Submission/aaaaaaaaaa.csv', index=False)

# %%
dropouts = [0.2, 0.3, 0.4, 0.6, 0.7, 0.8]
tempos = []
scores = []

for dropout in dropouts:
  print("Testando com {} dropout".format(dropout))
  ini = time.time()
  score_validation = cnn_rand(dropout)
  fim = time.time()
  tempo = fim - ini

  tempos.append(tempo)
  scores.append(score_validation)
  print()
# Out:
# Testando com 0.2 dropout
# Epoch 1/10
# 506/506 [==============================] - 214s 420ms/step - loss: 0.6698 - accuracy: 0.7034 - val_loss: 0.2502 - val_accuracy: 0.9472
# Epoch 2/10
# 506/506 [==============================] - 212s 419ms/step - loss: 0.1853 - accuracy: 0.9640 - val_loss: 0.1372 - val_accuracy: 0.9807
# Epoch 3/10
# 506/506 [==============================] - 212s 418ms/step - loss: 0.1198 - accuracy: 0.9818 - val_loss: 0.1115 - val_accuracy: 0.9847
# Epoch 4/10
# 506/506 [==============================] - 212s 419ms/step - loss: 0.0945 - accuracy: 0.9890 - val_loss: 0.1039 - val_accuracy: 0.9812
# Epoch 5/10
# 506/506 [==============================] - 212s 419ms/step - loss: 0.0766 - accuracy: 0.9918 - val_loss: 0.0691 - val_accuracy: 0.9890
# Epoch 6/10
# 506/506 [==============================] - 212s 418ms/step - loss: 0.0726 - accuracy: 0.9930 - val_loss: 0.0794 - val_accuracy: 0.9858
# Epoch 7/10
# 506/506 [==============================] - 212s 418ms/step - loss: 0.2020 - accuracy: 0.9910 - val_loss: 0.0701 - val_accuracy: 0.9853
# Epoch 8/10
# 506/506 [==============================] - 211s 417ms/step - loss: 0.0430 - accuracy: 0.9956 - val_loss: 0.0584 - val_accuracy: 0.9892
# Epoch 9/10
# 506/506 [==============================] - 211s 418ms/step - loss: 0.0389 - accuracy: 0.9964 - val_loss: 0.0539 - val_accuracy: 0.9895
# Epoch 10/10
# 506/506 [==============================] - 211s 417ms/step - loss: 0.0379 - accuracy: 0.9967 - val_loss: 0.0676 - val_accuracy: 0.9851
#
# Testando com 0.3 dropout
# Epoch 1/10
# 506/506 [==============================] - 211s 415ms/step - loss: 0.8166 - accuracy: 0.5325 - val_loss: 0.5070 - val_accuracy: 0.8540
# Epoch 2/10
# 506/506 [==============================] - 210s 415ms/step - loss: 0.2761 - accuracy: 0.9289 - val_loss: 0.1773 - val_accuracy: 0.9676
# Epoch 3/10
# 506/506 [==============================] - 210s 415ms/step - loss: 0.1540 - accuracy: 0.9707 - val_loss: 0.1349 - val_accuracy: 0.9767
# Epoch 4/10
# 506/506 [==============================] - 210s 414ms/step - loss: 0.1125 - accuracy: 0.9822 - val_loss: 0.1311 - val_accuracy: 0.9769
# Epoch 5/10
# 506/506 [==============================] - 210s 414ms/step - loss: 0.0913 - accuracy: 0.9875 - val_loss: 0.0963 - val_accuracy: 0.9860
# Epoch 6/10
# 506/506 [==============================] - 210s 415ms/step - loss: 0.0797 - accuracy: 0.9895 - val_loss: 0.0789 - val_accuracy: 0.9887
# Epoch 7/10
# 506/506 [==============================] - 210s 415ms/step - loss: 0.0690 - accuracy: 0.9913 - val_loss: 0.0756 - val_accuracy: 0.9862
# Epoch 8/10
# 506/506 [==============================] - 210s 415ms/step - loss: 0.0684 - accuracy: 0.9920 - val_loss: 0.0694 - val_accuracy: 0.9864
# Epoch 9/10
# 506/506 [==============================] - 212s 419ms/step - loss: 0.0531 - accuracy: 0.9937 - val_loss: 0.0738 - val_accuracy: 0.9838
# Epoch 10/10
# 506/506 [==============================] - 211s 416ms/step - loss: 0.0519 - accuracy: 0.9947 - val_loss: 0.0737 - val_accuracy: 0.9855
#
# Testando com 0.4 dropout
# Epoch 1/10
# 506/506 [==============================] - 216s 425ms/step - loss: 0.7512 - accuracy: 0.6196 - val_loss: 0.3116 - val_accuracy: 0.9200
# Epoch 2/10
# 506/506 [==============================] - 213s 421ms/step - loss: 0.2193 - accuracy: 0.9504 - val_loss: 0.1659 - val_accuracy: 0.9715
# Epoch 3/10
# 506/506 [==============================] - 212s 419ms/step - loss: 0.1339 - accuracy: 0.9775 - val_loss: 0.1339 - val_accuracy: 0.9755
# Epoch 4/10
# 506/506 [==============================] - 211s 417ms/step - loss: 0.0998 - accuracy: 0.9862 - val_loss: 0.1055 - val_accuracy: 0.9805
# Epoch 5/10
# 506/506 [==============================] - 211s 417ms/step - loss: 0.0849 - accuracy: 0.9893 - val_loss: 0.0768 - val_accuracy: 0.9886
# Epoch 6/10
# 506/506 [==============================] - 211s 417ms/step - loss: 0.0706 - accuracy: 0.9915 - val_loss: 0.0865 - val_accuracy: 0.9840
# Epoch 7/10
# 506/506 [==============================] - 211s 417ms/step - loss: 0.0704 - accuracy: 0.9924 - val_loss: 0.0810 - val_accuracy: 0.9845
# Epoch 8/10
# 506/506 [==============================] - 211s 417ms/step - loss: 0.0559 - accuracy: 0.9940 - val_loss: 0.0650 - val_accuracy: 0.9880
# Epoch 9/10
# 506/506 [==============================] - 211s 418ms/step - loss: 0.0524 - accuracy: 0.9951 - val_loss: 0.0614 - val_accuracy: 0.9899
# Epoch 10/10
# 506/506 [==============================] - 211s 417ms/step - loss: 0.0489 - accuracy: 0.9954 - val_loss: 0.0577 - val_accuracy: 0.9906
#
# Testando com 0.6 dropout
# Epoch 1/10
# 506/506 [==============================] - 213s 419ms/step - loss: 0.6592 - accuracy: 0.7169 - val_loss: 0.2547 - val_accuracy: 0.9480
# Epoch 2/10
# 506/506 [==============================] - 211s 418ms/step - loss: 0.1825 - accuracy: 0.9649 - val_loss: 0.1367 - val_accuracy: 0.9781
# Epoch 3/10
# 506/506 [==============================] - 211s 418ms/step - loss: 0.1257 - accuracy: 0.9821 - val_loss: 0.1088 - val_accuracy: 0.9816
# Epoch 4/10
# 506/506 [==============================] - 210s 416ms/step - loss: 0.0905 - accuracy: 0.9895 - val_loss: 0.1139 - val_accuracy: 0.9796
# Epoch 5/10
# 506/506 [==============================] - 211s 417ms/step - loss: 0.0802 - accuracy: 0.9920 - val_loss: 0.0726 - val_accuracy: 0.9878
# Epoch 6/10
# 506/506 [==============================] - 211s 416ms/step - loss: 0.0669 - accuracy: 0.9939 - val_loss: 0.0888 - val_accuracy: 0.9842
# Epoch 7/10
# 506/506 [==============================] - 211s 417ms/step - loss: 0.0576 - accuracy: 0.9954 - val_loss: 0.0685 - val_accuracy: 0.9874
# Epoch 8/10
# 506/506 [==============================] - 211s 417ms/step - loss: 0.0807 - accuracy: 0.9945 - val_loss: 0.0623 - val_accuracy: 0.9880
# Epoch 9/10
# 506/506 [==============================] - 211s 417ms/step - loss: 0.0440 - accuracy: 0.9964 - val_loss: 0.0592 - val_accuracy: 0.9859
# Epoch 10/10
# 506/506 [==============================] - 212s 419ms/step - loss: 0.1138 - accuracy: 0.9941 - val_loss: 0.0561 - val_accuracy: 0.9876
#
# Testando com 0.7 dropout
# Epoch 1/10
# 506/506 [==============================] - 218s 430ms/step - loss: 0.8056 - accuracy: 0.5522 - val_loss: 0.4295 - val_accuracy: 0.8821
# Epoch 2/10
# 506/506 [==============================] - 215s 425ms/step - loss: 0.2636 - accuracy: 0.9342 - val_loss: 0.1701 - val_accuracy: 0.9694
# Epoch 3/10
# 506/506 [==============================] - 215s 425ms/step - loss: 0.1504 - accuracy: 0.9726 - val_loss: 0.1482 - val_accuracy: 0.9735
# Epoch 4/10
# 506/506 [==============================] - 214s 424ms/step - loss: 0.1101 - accuracy: 0.9830 - val_loss: 0.1110 - val_accuracy: 0.9789
# Epoch 5/10
# 506/506 [==============================] - 214s 423ms/step - loss: 0.0912 - accuracy: 0.9876 - val_loss: 0.0830 - val_accuracy: 0.9871
# Epoch 6/10
# 506/506 [==============================] - 214s 423ms/step - loss: 0.0764 - accuracy: 0.9907 - val_loss: 0.0762 - val_accuracy: 0.9888
# Epoch 7/10
# 506/506 [==============================] - 215s 424ms/step - loss: 0.0671 - accuracy: 0.9920 - val_loss: 0.0774 - val_accuracy: 0.9863
# Epoch 8/10
# 506/506 [==============================] - 215s 426ms/step - loss: 0.0595 - accuracy: 0.9932 - val_loss: 0.0643 - val_accuracy: 0.9895
# Epoch 9/10
# 506/506 [==============================] - 215s 424ms/step - loss: 0.0535 - accuracy: 0.9938 - val_loss: 0.0616 - val_accuracy: 0.9900
# Epoch 10/10
# 506/506 [==============================] - 215s 424ms/step - loss: 0.0520 - accuracy: 0.9943 - val_loss: 0.0811 - val_accuracy: 0.9855
#
# Testando com 0.8 dropout
# Epoch 1/10
# 506/506 [==============================] - 216s 426ms/step - loss: 0.7490 - accuracy: 0.6220 - val_loss: 0.3063 - val_accuracy: 0.9246
# Epoch 2/10
# 506/506 [==============================] - 215s 425ms/step - loss: 0.2160 - accuracy: 0.9524 - val_loss: 0.1539 - val_accuracy: 0.9753
# Epoch 3/10
# 506/506 [==============================] - 218s 430ms/step - loss: 0.1303 - accuracy: 0.9791 - val_loss: 0.1323 - val_accuracy: 0.9754
# Epoch 4/10
# 506/506 [==============================] - 215s 425ms/step - loss: 0.0981 - accuracy: 0.9873 - val_loss: 0.1099 - val_accuracy: 0.9801
# Epoch 5/10
# 506/506 [==============================] - 214s 423ms/step - loss: 0.0803 - accuracy: 0.9902 - val_loss: 0.0721 - val_accuracy: 0.9896
# Epoch 6/10
# 506/506 [==============================] - 215s 425ms/step - loss: 0.0703 - accuracy: 0.9920 - val_loss: 0.0769 - val_accuracy: 0.9865
# Epoch 7/10
# 506/506 [==============================] - 215s 424ms/step - loss: 0.0662 - accuracy: 0.9928 - val_loss: 0.0875 - val_accuracy: 0.9826
# Epoch 8/10
# 506/506 [==============================] - 213s 422ms/step - loss: 0.0547 - accuracy: 0.9944 - val_loss: 0.0574 - val_accuracy: 0.9905
# Epoch 9/10
# 506/506 [==============================] - 214s 423ms/step - loss: 0.0635 - accuracy: 0.9942 - val_loss: 0.0689 - val_accuracy: 0.9865
# Epoch 10/10
# 506/506 [==============================] - 213s 421ms/step - loss: 0.2451 - accuracy: 0.9903 - val_loss: 0.0567 - val_accuracy: 0.9874

# %%
results = pd.DataFrame({
    'dropout': dropouts,
    'tempo': tempos,
    'score_validação': scores 
})

results.to_csv('Tempos_Dropouts_CNN.csv', index=False)

# %%
results.head(20)
# Out:
#    dropout        tempo  score_validação
# 0      0.2  2140.705642           0.9851
# 1      0.3  2120.896003           0.9855
# 2      0.4  2140.795713           0.9906
# 3      0.6  2133.331038           0.9875
# 4      0.7  2200.913389           0.9855
# 5      0.8  2200.713474           0.9874

# %%
# !zip -r /content/Model_Filters.zip /content/Model
# Out:
#   adding: content/Model/ (stored 0%)
#   adding: content/Model/model_0.8_dropout.h5 (deflated 16%)
#   adding: content/Model/model_0.6_dropout.h5 (deflated 15%)
#   adding: content/Model/model_0.2_dropout.h5 (deflated 16%)
#   adding: content/Model/model_0.7_dropout.h5 (deflated 16%)
#   adding: content/Model/model_0.3_dropout.h5 (deflated 16%)
#   adding: content/Model/model_0.4_dropout.h5 (deflated 16%)

# %%
# !zip -r /content/Submission_Filters.zip /content/Submission
# Out:
#   adding: content/Submission/ (stored 0%)
#   adding: content/Submission/0.4_dropout.csv (deflated 72%)
#   adding: content/Submission/0.3_dropout.csv (deflated 72%)
#   adding: content/Submission/0.8_dropout.csv (deflated 72%)
#   adding: content/Submission/0.6_dropout.csv (deflated 72%)
#   adding: content/Submission/0.2_dropout.csv (deflated 72%)
#   adding: content/Submission/0.7_dropout.csv (deflated 72%)

# %%
# !zip -r /content/Images.zip /content/Images
# Out:
#   adding: content/Images/ (stored 0%)
#   adding: content/Images/matriz_confusao_dropout_0.3.jpg (deflated 30%)
#   adding: content/Images/matriz_confusao_dropout_0.4.jpg (deflated 31%)
#   adding: content/Images/matriz_confusao_dropout_0.2.jpg (deflated 30%)
#   adding: content/Images/matriz_confusao_dropout_0.7.jpg (deflated 30%)
#   adding: content/Images/matriz_confusao_dropout_0.6.jpg (deflated 30%)
#   adding: content/Images/matriz_confusao_dropout_0.8.jpg (deflated 30%)

# %%
while True:
  pass
